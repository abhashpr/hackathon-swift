# %%
! yes | . ./setup.sh

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import re
import pickle5 as pickle
import os
import time
import json

# %%
start = time.perf_counter()

# %%
dirlist = ['models', 'data']

for dir_ in dirlist:
    try:
        os.makedirs(dir_)
    except:
        print(f'Could not make directory {dir_}')

# %% [markdown]
# #### Load longitude and latitude reference

# %%
# coords_dict = {}

# for pkl in os.listdir('.'):
#     if pkl.endswith('pkl'):
#         with open(pkl, 'rb') as f:
#             pkldata = pickle.load(f)
#             coords_dict.update(pkldata)
#         f.close()

# %%
# coords_dict = pickle.load(open('add_to_geo_map.pkl', 'rb'))

# %%
coords_dict = json.load(open('add_to_geo_map.json' , 'r'))

# %% [markdown]
# #### Connecting to the Database
# First we need to connect to the database with the data.

# %%
# %%time
# Connect to Postgres
import os
import psycopg2
def newCursor():
    try:
        connection = psycopg2.connect(user = os.environ["DB_USER"],
                                      host = os.environ["DB_HOST"],
                                      password = os.environ["DB_PASSWORD"],
                                      port = "5432",
                                      database = os.environ["DB_DATABASE"])

        cursor = connection.cursor()
        return cursor

    except (Exception, psycopg2.Error) as error:
        print("Error while connecting to PostgreSQL", error)
        return error
# Out:
# CPU times: user 6.09 ms, sys: 7.17 ms, total: 13.3 ms
# Wall time: 12.3 ms

# %% [markdown]
# #### Get the query result as a dataframe

# %%
# import pandas as pd

# c = newCursor()
# q = """
# SELECT
# -- regexp_matches(":32A:", '(\A[0-9]+)([A-Z][A-Z][A-Z])([0-9]+,[0-9]+)', 'g')
# -- regexp_matches(":32A:", '(\A[0-9]+).', 'g') as date
# FROM swift."simulated_fin_parsed_hackathon"
# LIMIT 10
# """
# c.execute(q)
# cols = [desc[0] for desc in c.description]
# df = pd.DataFrame(c.fetchall(), columns=cols)
# df.head(20)

# %%
# %%time
import pandas as pd

c = newCursor()
q = """
SELECT *
FROM swift."simulated_fin_parsed_hackathon"
-- LIMIT 10
"""
c.execute(q)
cols = [desc[0] for desc in c.description]
df = pd.DataFrame(c.fetchall(), columns=cols)
df.head()
# Out:
# CPU times: user 2.45 s, sys: 545 ms, total: 3 s
# Wall time: 3.08 s
#                                   UETR:    Sender  Receiver  \
# 0  bc95b4fb-fcf3-4d9f-a7b8-c641b16913ef  BIC68DF2  BIC6A94A
# 1  d4b46ac4-e22b-47e5-8385-335699c41166  BIC68DF2  BIC6A94A
# 2  758bd6ce-526d-4a08-a179-10ca089053b9  BIC68DF2  BIC6A94A
# 3  f435c830-a673-482a-83f4-74ded26ec666  BIC68DF2  BIC6A94A
# 4  22429a61-5fad-4481-b75f-e5fd8a241215  BIC68DF2  BIC6A94A
#
#                  :20: :23B:                 :32A:           :33B:  :36:  \
# 0    FIN001-NO-FX-679  CRED   210813RUB1544103,68   RUB1544103,68  None
# 1   FIN001-NO-FX-3374  CRED    210813RUB912070,95    RUB912070,95  None
# 2   FIN001-NO-FX-6478  CRED  210813RUB21760302,59  RUB21760302,59  None
# 3  FIN001-NO-FX-11185  CRED    210813RUB878587,53    RUB878587,53  None
# 4  FIN001-NO-FX-11284  CRED   210813RUB6696355,97   RUB6696355,97  None
#
#                                                :50A: :50F: :50K:        :52A:  \
# 0  /0000000000000000000000000000009621\n BIC68DF2C94  None  None  BIC68DF2C94
# 1  /0000000000000000000000000000007346\n BIC68DF2C94  None  None  BIC68DF2C94
# 2  /0000000000000000000000000000005305\n BIC68DF2C94  None  None  BIC68DF2C94
# 3  /0000000000000000000000000000004127\n BIC68DF2C94  None  None  BIC68DF2C94
# 4  /0000000000000000000000000000006978\n BIC68DF2C94  None  None  BIC68DF2C94
#
#   :56A:        :57A:                                              :59F: :71A:  \
# 0  None  BIC6A94AE24  /0000000000000000000000000000006099\n 1/ANGEL ...   SHA
# 1  None  BIC6A94AE24  /0000000000000000000000000000000874\n 1/JAKUB ...   BEN
# 2  None  BIC6A94AE24  /0000000000000000000000000000005436\n 1/ZIGA M...   SHA
# 3  None  BIC6A94AE24  /0000000000000000000000000000008707\n 1/YAEL D...   SHA
# 4  None  BIC6A94AE24  /0000000000000000000000000000004326\n 1/NOEL P...   SHA
#
#      :71F: :71G:  :79:  Type
# 0     None  None  None   103
# 1  RUB0,00  None  None   103
# 2     None  None  None   103
# 3     None  None  None   103
# 4     None  None  None   103

# %%
print(df[df[':50A:'] != ""].shape)
print(df[df[':50F:'] != ""].shape)
print(df[df[':50K:'] != ""].shape)
# Out:
# (379526, 20)
# (379526, 20)
# (379526, 20)

# %% [markdown]
# #### Remove nan values

# %%
# %%time
import numpy as np
import re

df = df.replace(np.nan, '', regex=True)
# Out:
# CPU times: user 583 ms, sys: 27.2 ms, total: 610 ms
# Wall time: 607 ms

# %% [markdown]
# #### Create a new dataframe for transformed attributes

# %%
dfm = pd.DataFrame()

# %%
import concurrent.futures
from functools import partial

# %%
# simple wrapper code around serial_calc to parallelize the work
def parallel_calc(df, func, n_core, col):
    futs = []
    df_split = np.array_split(df, n_core)
    # pool = concurrent.futures.ThreadPoolExecutor(max_workers = n_core)
    pool = concurrent.futures.ProcessPoolExecutor(max_workers = n_core)
    apply_partial = partial(func, col=col)
    return pd.concat(pool.map(apply_partial, df_split))

# %% [markdown]
# #### Create DATETIME field

# %%
# %%time
def datefunc(row, col):
    return pd.to_datetime(re.search('([0-9]+)?', row[col]).group(0), 
                             format='%y%m%d', 
                             errors='ignore')

def serial_proc_datefunc(df, col):
    apply_partial = partial(datefunc, col=col)
    df['32a_val_dt'] = df.apply(apply_partial, axis=1)
    return df

dfm['32a_val_dt'] = parallel_calc(df, serial_proc_datefunc, 8, ':32A:')['32a_val_dt']
# dfm['32a_val_dt'] = serial_proc_datefunc(df, ':32A:')['32a_val_dt']
# Out:
# CPU times: user 3.11 s, sys: 1.23 s, total: 4.34 s
# Wall time: 24.9 s

# %%
dfm
# Out:
#        32a_val_dt
# 0      2021-08-13
# 1      2021-08-13
# 2      2021-08-13
# 3      2021-08-13
# 4      2021-08-13
# ...           ...
# 379521 2021-08-13
# 379522 2021-08-13
# 379523 2021-08-13
# 379524 2021-08-13
# 379525 2021-08-13
#
# [379526 rows x 1 columns]

# %%
# %%time
# dfm['32a_val_dt_yr'] = pd.DatetimeIndex(dfm['32a_val_dt']).year
# dfm['32a_val_dt_mth'] = pd.DatetimeIndex(dfm['32a_val_dt']).month
# dfm['32a_val_dt_day'] = pd.DatetimeIndex(dfm['32a_val_dt']).day

# %% [markdown]
# #### Split 33B into Currency and Amount

# %%
# %%time
def _33bcurAmt(row, col):
    return pd.Series(re.split("(^[A-Z][A-Z][A-Z])([0-9]*,[0-9]*)", row[col])[1:3], 
                                index=[['cur', 'amt']])

def serial_proc_33bcurAmt(df, col):
    apply_partial = partial(_33bcurAmt, col=col)
    df[['33b_cur', '33b_orig_ord_amt']] = df.apply(apply_partial, axis=1)
    return df

dfm[['33b_cur', '33b_orig_ord_amt']] = parallel_calc(df, serial_proc_33bcurAmt, 8, ':33B:')[['33b_cur', '33b_orig_ord_amt']]
# dfm[['33b_cur', '33b_orig_ord_amt']] = serial_proc_33bcurAmt(df, ':33B:')[['33b_cur', '33b_orig_ord_amt']]
# Out:
# CPU times: user 3.84 s, sys: 1.43 s, total: 5.27 s
# Wall time: 2min 19s

# %%
dfm
# Out:
#        32a_val_dt 33b_cur 33b_orig_ord_amt
# 0      2021-08-13     RUB       1544103,68
# 1      2021-08-13     RUB        912070,95
# 2      2021-08-13     RUB      21760302,59
# 3      2021-08-13     RUB        878587,53
# 4      2021-08-13     RUB       6696355,97
# ...           ...     ...              ...
# 379521 2021-08-13     USD          8339,00
# 379522 2021-08-13     USD          4001,56
# 379523 2021-08-13     USD          4456,00
# 379524 2021-08-13     USD          8836,10
# 379525 2021-08-13     USD          4031,02
#
# [379526 rows x 3 columns]

# %% [markdown]
# #### 50A Payor Lattitude and Longitude

# %%
# %%time
def _50aPayor(row, col):
    return pd.Series(row[col].split("\n") if len(row[col]) > 0 else [''] * 2,
                                  index=['lat', 'lon'])

def serial_proc_50aPayor(df, col):
    apply_partial = partial(_50aPayor, col=col)
    df[['50a_payor_lon', '50a_payor_lat']] = df.apply(apply_partial, axis=1)
    return df

dfm[['50a_payor_lon', '50a_payor_lat']] = parallel_calc(df, serial_proc_50aPayor, 8, ':50A:')[['50a_payor_lon', '50a_payor_lat']]
# dfm[['50a_payor_lon', '50a_payor_lat']] = serial_proc_50aPayor(df, ':50A:')[['50a_payor_lon', '50a_payor_lat']]
# Out:
# CPU times: user 3.73 s, sys: 1.3 s, total: 5.04 s
# Wall time: 56.5 s

# %%
dfm
# Out:
#        32a_val_dt 33b_cur 33b_orig_ord_amt  \
# 0      2021-08-13     RUB       1544103,68
# 1      2021-08-13     RUB        912070,95
# 2      2021-08-13     RUB      21760302,59
# 3      2021-08-13     RUB        878587,53
# 4      2021-08-13     RUB       6696355,97
# ...           ...     ...              ...
# 379521 2021-08-13     USD          8339,00
# 379522 2021-08-13     USD          4001,56
# 379523 2021-08-13     USD          4456,00
# 379524 2021-08-13     USD          8836,10
# 379525 2021-08-13     USD          4031,02
#
#                               50a_payor_lon 50a_payor_lat
# 0       /0000000000000000000000000000009621   BIC68DF2C94
# 1       /0000000000000000000000000000007346   BIC68DF2C94
# 2       /0000000000000000000000000000005305   BIC68DF2C94
# 3       /0000000000000000000000000000004127   BIC68DF2C94
# 4       /0000000000000000000000000000006978   BIC68DF2C94
# ...                                     ...           ...
# 379521  /0000000000000000000000000000003030   BIC6A94AE24
# 379522
# 379523
# 379524  /0000000000000000000000000000007977   BIC6A94AE24
# 379525
#
# [379526 rows x 5 columns]

# %% [markdown]
# #### Split 50F - Payor ACCT_NUM, PAYOR_NAME, PAYOR_ADDRESS_LINE_1, PAYOR_ADDRESS_LINE_2

# %%
# %%time
def _50fPayor(row, col):
    return pd.Series(re.sub(r"[0-9]?\/", " ", row[col]).split("\n") 
                                            if len(row[col]) > 0 else [''] * 4,
                                            index=['ACCOUNT_NUM', 'NAME', 'ADDRESS_LN_1', 'ADDRESS_LN_2'])

def serial_proc_50fPayor(df, col):
    apply_partial = partial(_50fPayor, col=col)
    df[['50f_payor_acct_nm:', '50f_payor_name:', 
     '50f_payor_add_ln_1', '50f_payor_add_ln_2']] = df.apply(apply_partial, axis=1)
    return df

dfm[['50f_payor_acct_nm:', '50f_payor_name:', 
     '50f_payor_add_ln_1', '50f_payor_add_ln_2']] = parallel_calc(df, serial_proc_50fPayor, 
                                                    8, ':50F:') \
                                                    [['50f_payor_acct_nm:', '50f_payor_name:', 
                                                    '50f_payor_add_ln_1', '50f_payor_add_ln_2']]

# dfm[['50f_payor_acct_nm:', '50f_payor_name:', 
#      '50f_payor_add_ln_1', '50f_payor_add_ln_2']] = serial_proc_50fPayor(df, ':50F:') [['50f_payor_acct_nm:', '50f_payor_name:', 
#                                                                                         '50f_payor_add_ln_1', '50f_payor_add_ln_2']]
# Out:
# CPU times: user 3.73 s, sys: 1.22 s, total: 4.95 s
# Wall time: 57.2 s

# %%
dfm
# Out:
#        32a_val_dt 33b_cur 33b_orig_ord_amt  \
# 0      2021-08-13     RUB       1544103,68
# 1      2021-08-13     RUB        912070,95
# 2      2021-08-13     RUB      21760302,59
# 3      2021-08-13     RUB        878587,53
# 4      2021-08-13     RUB       6696355,97
# ...           ...     ...              ...
# 379521 2021-08-13     USD          8339,00
# 379522 2021-08-13     USD          4001,56
# 379523 2021-08-13     USD          4456,00
# 379524 2021-08-13     USD          8836,10
# 379525 2021-08-13     USD          4031,02
#
#                               50a_payor_lon 50a_payor_lat  \
# 0       /0000000000000000000000000000009621   BIC68DF2C94
# 1       /0000000000000000000000000000007346   BIC68DF2C94
# 2       /0000000000000000000000000000005305   BIC68DF2C94
# 3       /0000000000000000000000000000004127   BIC68DF2C94
# 4       /0000000000000000000000000000006978   BIC68DF2C94
# ...                                     ...           ...
# 379521  /0000000000000000000000000000003030   BIC6A94AE24
# 379522
# 379523
# 379524  /0000000000000000000000000000007977   BIC6A94AE24
# 379525
#
#            50f_payor_acct_nm:     50f_payor_name:        50f_payor_add_ln_1  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                 ...                       ...
# 379521
# 379522  DRLC US VA 0000008040    EMILIJA MITCHELL    345256 YELLOW BRICK RD
# 379523  DRLC US VA 0000009910      JOO-WON GARCIA    521469 LAKE POINTE AVE
# 379524
# 379525
#
#        50f_payor_add_ln_2
# 0
# 1
# 2
# 3
# 4
# ...                   ...
# 379521
# 379522         US LINCOLN
# 379523         US MIFFLIN
# 379524
# 379525
#
# [379526 rows x 9 columns]

# %% [markdown]
# #### Convert sender and receiver to their frequecy count

# %%
# %%time
# dfm['52a_sender'] = df.loc[:, ":52A:"].apply(lambda x: senders_count_dict[x])
dfm['52a_sender'] = df.loc[:, ":52A:"]
# Out:
# CPU times: user 8.51 ms, sys: 150 µs, total: 8.66 ms
# Wall time: 8.22 ms

# %%
# %%time
# dfm['57a_receiver'] = df.loc[:, ":57A:"].apply(lambda x: receivers_count_dict[x])
dfm['57a_receiver'] = df.loc[:, ":57A:"]
# Out:
# CPU times: user 5.72 ms, sys: 3.27 ms, total: 8.98 ms
# Wall time: 8.06 ms

# %%
def get_geocodes(address):
    try:
        # return coords_dict[address]
        location = coords_dict[address]
        return [location['latitude'], location['longitude']]
    except:
        return ''

# %%
# %%time

def _50fPayorCoords(row, col):
    return pd.Series(get_geocodes(row[col].strip()), 
                        index=['latitude', 'longitude'])

def serial_proc_50fPayorCoords(df, col):
    apply_partial = partial(_50fPayorCoords, col=col)
    df[['50f_payor_add_lat', '50f_payor_add_lon']] = df.apply(apply_partial, axis=1)
    return df

dfm[['50f_payor_add_lat', 
     '50f_payor_add_lon']] = parallel_calc(dfm, serial_proc_50fPayorCoords, 
                                           8, '50f_payor_add_ln_2') \
                                           [['50f_payor_add_lat', '50f_payor_add_lon']]
# Out:
# CPU times: user 1.4 s, sys: 520 ms, total: 1.92 s
# Wall time: 54.2 s

# %%
dfm
# Out:
#        32a_val_dt 33b_cur 33b_orig_ord_amt  \
# 0      2021-08-13     RUB       1544103,68
# 1      2021-08-13     RUB        912070,95
# 2      2021-08-13     RUB      21760302,59
# 3      2021-08-13     RUB        878587,53
# 4      2021-08-13     RUB       6696355,97
# ...           ...     ...              ...
# 379521 2021-08-13     USD          8339,00
# 379522 2021-08-13     USD          4001,56
# 379523 2021-08-13     USD          4456,00
# 379524 2021-08-13     USD          8836,10
# 379525 2021-08-13     USD          4031,02
#
#                               50a_payor_lon 50a_payor_lat  \
# 0       /0000000000000000000000000000009621   BIC68DF2C94
# 1       /0000000000000000000000000000007346   BIC68DF2C94
# 2       /0000000000000000000000000000005305   BIC68DF2C94
# 3       /0000000000000000000000000000004127   BIC68DF2C94
# 4       /0000000000000000000000000000006978   BIC68DF2C94
# ...                                     ...           ...
# 379521  /0000000000000000000000000000003030   BIC6A94AE24
# 379522
# 379523
# 379524  /0000000000000000000000000000007977   BIC6A94AE24
# 379525
#
#            50f_payor_acct_nm:     50f_payor_name:        50f_payor_add_ln_1  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                 ...                       ...
# 379521
# 379522  DRLC US VA 0000008040    EMILIJA MITCHELL    345256 YELLOW BRICK RD
# 379523  DRLC US VA 0000009910      JOO-WON GARCIA    521469 LAKE POINTE AVE
# 379524
# 379525
#
#        50f_payor_add_ln_2   52a_sender 57a_receiver 50f_payor_add_lat  \
# 0                          BIC68DF2C94  BIC6A94AE24
# 1                          BIC68DF2C94  BIC6A94AE24
# 2                          BIC68DF2C94  BIC6A94AE24
# 3                          BIC68DF2C94  BIC6A94AE24
# 4                          BIC68DF2C94  BIC6A94AE24
# ...                   ...          ...          ...               ...
# 379521                     BIC6A94AE24  BIC68DF2C94
# 379522         US LINCOLN  BIC6A94AE24  BIC68DF2C94           40.8089
# 379523         US MIFFLIN  BIC6A94AE24  BIC68DF2C94           37.9412
# 379524                     BIC6A94AE24  BIC68DF2C94
# 379525                     BIC6A94AE24  BIC68DF2C94
#
#        50f_payor_add_lon
# 0
# 1
# 2
# 3
# 4
# ...                  ...
# 379521
# 379522          -96.7078
# 379523          -81.8221
# 379524
# 379525
#
# [379526 rows x 13 columns]

# %%
# %%time

def _50kPayorSplit(row, col):
    return pd.Series(re.sub(r"[0-9]?\/", " ", row[col]).split("\n") 
                        if len(row[col]) > 0 else [''] * 4,
                        index=['acct_num', 'name', 'add_ln_1', 'add_ln_2'])

def serial_proc_50kPayorSplit(df, col):
    apply_partial = partial(_50kPayorSplit, col=col)
    df[['50k_payor_acct_num:', '50k_payor_name', 
     '50k_payor_add_ln_1', '50k_payor_add_ln_2']] = df.apply(apply_partial, axis=1)
    return df

dfm[['50k_payor_acct_num:', '50k_payor_name', 
     '50k_payor_add_ln_1', '50k_payor_add_ln_2']] = parallel_calc(df, serial_proc_50kPayorSplit, 
                                                        8, ':50K:') \
                                                        [['50k_payor_acct_num:', '50k_payor_name', 
                                                          '50k_payor_add_ln_1', '50k_payor_add_ln_2']]
# Out:
# CPU times: user 3.54 s, sys: 1.42 s, total: 4.95 s
# Wall time: 59.3 s

# %%
dfm
# Out:
#        32a_val_dt 33b_cur 33b_orig_ord_amt  \
# 0      2021-08-13     RUB       1544103,68
# 1      2021-08-13     RUB        912070,95
# 2      2021-08-13     RUB      21760302,59
# 3      2021-08-13     RUB        878587,53
# 4      2021-08-13     RUB       6696355,97
# ...           ...     ...              ...
# 379521 2021-08-13     USD          8339,00
# 379522 2021-08-13     USD          4001,56
# 379523 2021-08-13     USD          4456,00
# 379524 2021-08-13     USD          8836,10
# 379525 2021-08-13     USD          4031,02
#
#                               50a_payor_lon 50a_payor_lat  \
# 0       /0000000000000000000000000000009621   BIC68DF2C94
# 1       /0000000000000000000000000000007346   BIC68DF2C94
# 2       /0000000000000000000000000000005305   BIC68DF2C94
# 3       /0000000000000000000000000000004127   BIC68DF2C94
# 4       /0000000000000000000000000000006978   BIC68DF2C94
# ...                                     ...           ...
# 379521  /0000000000000000000000000000003030   BIC6A94AE24
# 379522
# 379523
# 379524  /0000000000000000000000000000007977   BIC6A94AE24
# 379525
#
#            50f_payor_acct_nm:     50f_payor_name:        50f_payor_add_ln_1  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                 ...                       ...
# 379521
# 379522  DRLC US VA 0000008040    EMILIJA MITCHELL    345256 YELLOW BRICK RD
# 379523  DRLC US VA 0000009910      JOO-WON GARCIA    521469 LAKE POINTE AVE
# 379524
# 379525
#
#        50f_payor_add_ln_2   52a_sender 57a_receiver 50f_payor_add_lat  \
# 0                          BIC68DF2C94  BIC6A94AE24
# 1                          BIC68DF2C94  BIC6A94AE24
# 2                          BIC68DF2C94  BIC6A94AE24
# 3                          BIC68DF2C94  BIC6A94AE24
# 4                          BIC68DF2C94  BIC6A94AE24
# ...                   ...          ...          ...               ...
# 379521                     BIC6A94AE24  BIC68DF2C94
# 379522         US LINCOLN  BIC6A94AE24  BIC68DF2C94           40.8089
# 379523         US MIFFLIN  BIC6A94AE24  BIC68DF2C94           37.9412
# 379524                     BIC6A94AE24  BIC68DF2C94
# 379525                     BIC6A94AE24  BIC68DF2C94
#
#        50f_payor_add_lon                  50k_payor_acct_num:  \
# 0
# 1
# 2
# 3
# 4
# ...                  ...                                  ...
# 379521
# 379522          -96.7078
# 379523          -81.8221
# 379524
# 379525                     0000000000000000000000000000007510
#
#             50k_payor_name      50k_payor_add_ln_1 50k_payor_add_ln_2
# 0
# 1
# 2
# 3
# 4
# ...                    ...                     ...                ...
# 379521
# 379522
# 379523
# 379524
# 379525    MATILDE PETERSON    493705 SHAMROCK BLVD       US STONEWALL
#
# [379526 rows x 17 columns]

# %%
# %%time

def _50kPayorCoords(row, col):
    return pd.Series(get_geocodes(row[col].strip()), 
                        index=['latitude', 'longitude'])

def serial_proc_50kPayorCoords(df, col):
    apply_partial = partial(_50kPayorCoords, col=col)
    df[['50k_payor_add_lat', '50k_payor_add_lon']] = df.apply(apply_partial, axis=1)
    return df

dfm[['50k_payor_add_lat', '50k_payor_add_lon']] = parallel_calc(dfm, serial_proc_50kPayorCoords, 
                                                            8, '50k_payor_add_ln_2') \
                                                            [['50k_payor_add_lat', '50k_payor_add_lon']]
# Out:
# CPU times: user 1.94 s, sys: 668 ms, total: 2.61 s
# Wall time: 54.6 s

# %%
dfm
# Out:
#        32a_val_dt 33b_cur 33b_orig_ord_amt  \
# 0      2021-08-13     RUB       1544103,68
# 1      2021-08-13     RUB        912070,95
# 2      2021-08-13     RUB      21760302,59
# 3      2021-08-13     RUB        878587,53
# 4      2021-08-13     RUB       6696355,97
# ...           ...     ...              ...
# 379521 2021-08-13     USD          8339,00
# 379522 2021-08-13     USD          4001,56
# 379523 2021-08-13     USD          4456,00
# 379524 2021-08-13     USD          8836,10
# 379525 2021-08-13     USD          4031,02
#
#                               50a_payor_lon 50a_payor_lat  \
# 0       /0000000000000000000000000000009621   BIC68DF2C94
# 1       /0000000000000000000000000000007346   BIC68DF2C94
# 2       /0000000000000000000000000000005305   BIC68DF2C94
# 3       /0000000000000000000000000000004127   BIC68DF2C94
# 4       /0000000000000000000000000000006978   BIC68DF2C94
# ...                                     ...           ...
# 379521  /0000000000000000000000000000003030   BIC6A94AE24
# 379522
# 379523
# 379524  /0000000000000000000000000000007977   BIC6A94AE24
# 379525
#
#            50f_payor_acct_nm:     50f_payor_name:        50f_payor_add_ln_1  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                 ...                       ...
# 379521
# 379522  DRLC US VA 0000008040    EMILIJA MITCHELL    345256 YELLOW BRICK RD
# 379523  DRLC US VA 0000009910      JOO-WON GARCIA    521469 LAKE POINTE AVE
# 379524
# 379525
#
#        50f_payor_add_ln_2   52a_sender 57a_receiver 50f_payor_add_lat  \
# 0                          BIC68DF2C94  BIC6A94AE24
# 1                          BIC68DF2C94  BIC6A94AE24
# 2                          BIC68DF2C94  BIC6A94AE24
# 3                          BIC68DF2C94  BIC6A94AE24
# 4                          BIC68DF2C94  BIC6A94AE24
# ...                   ...          ...          ...               ...
# 379521                     BIC6A94AE24  BIC68DF2C94
# 379522         US LINCOLN  BIC6A94AE24  BIC68DF2C94           40.8089
# 379523         US MIFFLIN  BIC6A94AE24  BIC68DF2C94           37.9412
# 379524                     BIC6A94AE24  BIC68DF2C94
# 379525                     BIC6A94AE24  BIC68DF2C94
#
#        50f_payor_add_lon                  50k_payor_acct_num:  \
# 0
# 1
# 2
# 3
# 4
# ...                  ...                                  ...
# 379521
# 379522          -96.7078
# 379523          -81.8221
# 379524
# 379525                     0000000000000000000000000000007510
#
#             50k_payor_name      50k_payor_add_ln_1 50k_payor_add_ln_2  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...                     ...                ...
# 379521
# 379522
# 379523
# 379524
# 379525    MATILDE PETERSON    493705 SHAMROCK BLVD       US STONEWALL
#
#        50k_payor_add_lat 50k_payor_add_lon
# 0
# 1
# 2
# 3
# 4
# ...                  ...               ...
# 379521
# 379522
# 379523
# 379524
# 379525           33.1572          -100.245
#
# [379526 rows x 19 columns]

# %%
# %%time

def _59fbeneficiarySplit(row, col):
    return pd.Series(re.sub(r"[0-9]?\/", " ", row[col]).split("\n") 
                if len(row[col]) > 0 else [''] * 4,
                index=['acct_num', 'name', 'add_ln_1', 'add_ln_2'])

def serial_proc_59fbeneficiarySplit(df, col):
    apply_partial = partial(_59fbeneficiarySplit, col=col)
    df[['59f_ben_acct_num:', '59f_ben_name', 
     '59f_ben_add_ln_1', '59f_ben_add_ln_2']] = df.apply(apply_partial, axis=1)
    return df

dfm[['59f_ben_acct_num:', '59f_ben_name', 
     '59f_ben_add_ln_1', '59f_ben_add_ln_2']] = parallel_calc(df, serial_proc_59fbeneficiarySplit, 
                                                    8, ':59F:') \
                                                    [['59f_ben_acct_num:', '59f_ben_name', 
                                                      '59f_ben_add_ln_1', '59f_ben_add_ln_2']]
# Out:
# CPU times: user 4.02 s, sys: 1.45 s, total: 5.47 s
# Wall time: 60 s

# %%
dfm
# Out:
#        32a_val_dt 33b_cur 33b_orig_ord_amt  \
# 0      2021-08-13     RUB       1544103,68
# 1      2021-08-13     RUB        912070,95
# 2      2021-08-13     RUB      21760302,59
# 3      2021-08-13     RUB        878587,53
# 4      2021-08-13     RUB       6696355,97
# ...           ...     ...              ...
# 379521 2021-08-13     USD          8339,00
# 379522 2021-08-13     USD          4001,56
# 379523 2021-08-13     USD          4456,00
# 379524 2021-08-13     USD          8836,10
# 379525 2021-08-13     USD          4031,02
#
#                               50a_payor_lon 50a_payor_lat  \
# 0       /0000000000000000000000000000009621   BIC68DF2C94
# 1       /0000000000000000000000000000007346   BIC68DF2C94
# 2       /0000000000000000000000000000005305   BIC68DF2C94
# 3       /0000000000000000000000000000004127   BIC68DF2C94
# 4       /0000000000000000000000000000006978   BIC68DF2C94
# ...                                     ...           ...
# 379521  /0000000000000000000000000000003030   BIC6A94AE24
# 379522
# 379523
# 379524  /0000000000000000000000000000007977   BIC6A94AE24
# 379525
#
#            50f_payor_acct_nm:     50f_payor_name:        50f_payor_add_ln_1  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                 ...                       ...
# 379521
# 379522  DRLC US VA 0000008040    EMILIJA MITCHELL    345256 YELLOW BRICK RD
# 379523  DRLC US VA 0000009910      JOO-WON GARCIA    521469 LAKE POINTE AVE
# 379524
# 379525
#
#        50f_payor_add_ln_2   52a_sender  ...  \
# 0                          BIC68DF2C94  ...
# 1                          BIC68DF2C94  ...
# 2                          BIC68DF2C94  ...
# 3                          BIC68DF2C94  ...
# 4                          BIC68DF2C94  ...
# ...                   ...          ...  ...
# 379521                     BIC6A94AE24  ...
# 379522         US LINCOLN  BIC6A94AE24  ...
# 379523         US MIFFLIN  BIC6A94AE24  ...
# 379524                     BIC6A94AE24  ...
# 379525                     BIC6A94AE24  ...
#
#                         50k_payor_acct_num:      50k_payor_name  \
# 0
# 1
# 2
# 3
# 4
# ...                                     ...                 ...
# 379521
# 379522
# 379523
# 379524
# 379525   0000000000000000000000000000007510    MATILDE PETERSON
#
#             50k_payor_add_ln_1 50k_payor_add_ln_2 50k_payor_add_lat  \
# 0
# 1
# 2
# 3
# 4
# ...                        ...                ...               ...
# 379521
# 379522
# 379523
# 379524
# 379525    493705 SHAMROCK BLVD       US STONEWALL           33.1572
#
#        50k_payor_add_lon                    59f_ben_acct_num:  \
# 0                          0000000000000000000000000000006099
# 1                          0000000000000000000000000000000874
# 2                          0000000000000000000000000000005436
# 3                          0000000000000000000000000000008707
# 4                          0000000000000000000000000000004326
# ...                  ...                                  ...
# 379521                     0000000000000000000000000000003627
# 379522                     0000000000000000000000000000009377
# 379523                     0000000000000000000000000000001708
# 379524                     0000000000000000000000000000005070
# 379525          -100.245   0000000000000000000000000000000600
#
#                59f_ben_name          59f_ben_add_ln_1  \
# 0               ANGEL JAMES          1789 PHILLIPS RD
# 1               JAKUB EVANS            369653 PEAR ST
# 2             ZIGA MITCHELL           131041 DEBRA DR
# 3               YAEL DEMERS        50438 HAYMARKET ST
# 4               NOEL PLANTE           43790 MOSHER CT
# ...                     ...                       ...
# 379521       JESSE LEFEBVRE        147085 CAPITOL AVE
# 379522        SULTAN OZTURK       120952 PONDEROSA DR
# 379523    DIMITRIOS PASCUAL     134541 E NORTHGATE CT
# 379524         ADAMA YILDIZ    55827 PRESERVATION WAY
# 379525         CLARA SAVARD        216562 WINDFALL CT
#
#                 59f_ben_add_ln_2
# 0                    US GLENDALE
# 1                       US WELLS
# 2                      US GROVER
# 3                       US MOORE
# 4                    US WAUCHULA
# ...                          ...
# 379521    US SOUTH SAN FRANCISCO
# 379522               US WARETOWN
# 379523          US COMMERCE CITY
# 379524             US ESTES PARK
# 379525                  US GALAX
#
# [379526 rows x 23 columns]

# %%
# %%time

def _59fBeneficiaryCoords(row, col):
    return pd.Series(get_geocodes(row[col].strip()), 
                        index=['latitude', 'longitude'])

def serial_proc_59fBeneficiaryCoords(df, col):
    apply_partial = partial(_59fBeneficiaryCoords, col=col)
    df[['59f_ben_add_lat', '59f_ben_add_lon']] = df.apply(apply_partial, axis=1)
    return df

dfm[['59f_ben_add_lat', '59f_ben_add_lon']] = parallel_calc(dfm, serial_proc_59fBeneficiaryCoords, 
                                                           8, '59f_ben_add_ln_2') \
                                                           [['59f_ben_add_lat', '59f_ben_add_lon']]
# Out:
# CPU times: user 3.07 s, sys: 1e+03 ms, total: 4.07 s
# Wall time: 53.5 s

# %%
dfm
# Out:
#        32a_val_dt 33b_cur 33b_orig_ord_amt  \
# 0      2021-08-13     RUB       1544103,68
# 1      2021-08-13     RUB        912070,95
# 2      2021-08-13     RUB      21760302,59
# 3      2021-08-13     RUB        878587,53
# 4      2021-08-13     RUB       6696355,97
# ...           ...     ...              ...
# 379521 2021-08-13     USD          8339,00
# 379522 2021-08-13     USD          4001,56
# 379523 2021-08-13     USD          4456,00
# 379524 2021-08-13     USD          8836,10
# 379525 2021-08-13     USD          4031,02
#
#                               50a_payor_lon 50a_payor_lat  \
# 0       /0000000000000000000000000000009621   BIC68DF2C94
# 1       /0000000000000000000000000000007346   BIC68DF2C94
# 2       /0000000000000000000000000000005305   BIC68DF2C94
# 3       /0000000000000000000000000000004127   BIC68DF2C94
# 4       /0000000000000000000000000000006978   BIC68DF2C94
# ...                                     ...           ...
# 379521  /0000000000000000000000000000003030   BIC6A94AE24
# 379522
# 379523
# 379524  /0000000000000000000000000000007977   BIC6A94AE24
# 379525
#
#            50f_payor_acct_nm:     50f_payor_name:        50f_payor_add_ln_1  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                 ...                       ...
# 379521
# 379522  DRLC US VA 0000008040    EMILIJA MITCHELL    345256 YELLOW BRICK RD
# 379523  DRLC US VA 0000009910      JOO-WON GARCIA    521469 LAKE POINTE AVE
# 379524
# 379525
#
#        50f_payor_add_ln_2   52a_sender  ...      50k_payor_add_ln_1  \
# 0                          BIC68DF2C94  ...
# 1                          BIC68DF2C94  ...
# 2                          BIC68DF2C94  ...
# 3                          BIC68DF2C94  ...
# 4                          BIC68DF2C94  ...
# ...                   ...          ...  ...                     ...
# 379521                     BIC6A94AE24  ...
# 379522         US LINCOLN  BIC6A94AE24  ...
# 379523         US MIFFLIN  BIC6A94AE24  ...
# 379524                     BIC6A94AE24  ...
# 379525                     BIC6A94AE24  ...    493705 SHAMROCK BLVD
#
#        50k_payor_add_ln_2 50k_payor_add_lat 50k_payor_add_lon  \
# 0
# 1
# 2
# 3
# 4
# ...                   ...               ...               ...
# 379521
# 379522
# 379523
# 379524
# 379525       US STONEWALL           33.1572          -100.245
#
#                           59f_ben_acct_num:         59f_ben_name  \
# 0        0000000000000000000000000000006099          ANGEL JAMES
# 1        0000000000000000000000000000000874          JAKUB EVANS
# 2        0000000000000000000000000000005436        ZIGA MITCHELL
# 3        0000000000000000000000000000008707          YAEL DEMERS
# 4        0000000000000000000000000000004326          NOEL PLANTE
# ...                                     ...                  ...
# 379521   0000000000000000000000000000003627       JESSE LEFEBVRE
# 379522   0000000000000000000000000000009377        SULTAN OZTURK
# 379523   0000000000000000000000000000001708    DIMITRIOS PASCUAL
# 379524   0000000000000000000000000000005070         ADAMA YILDIZ
# 379525   0000000000000000000000000000000600         CLARA SAVARD
#
#                 59f_ben_add_ln_1          59f_ben_add_ln_2 59f_ben_add_lat  \
# 0               1789 PHILLIPS RD               US GLENDALE         34.1469
# 1                 369653 PEAR ST                  US WELLS         47.5664
# 2                131041 DEBRA DR                 US GROVER         42.7956
# 3             50438 HAYMARKET ST                  US MOORE         35.8156
# 4                43790 MOSHER CT               US WAUCHULA         27.5473
# ...                          ...                       ...             ...
# 379521        147085 CAPITOL AVE    US SOUTH SAN FRANCISCO         37.6535
# 379522       120952 PONDEROSA DR               US WARETOWN         39.7939
# 379523     134541 E NORTHGATE CT          US COMMERCE CITY         39.8083
# 379524    55827 PRESERVATION WAY             US ESTES PARK         40.3664
# 379525        216562 WINDFALL CT                  US GALAX         36.6612
#
#        59f_ben_add_lon
# 0             -118.248
# 1             -99.6509
# 2             -110.929
# 3              -101.91
# 4             -81.8115
# ...                ...
# 379521        -122.417
# 379522        -74.2232
# 379523        -104.934
# 379524        -105.503
# 379525         -80.924
#
# [379526 rows x 25 columns]

# %%
dfm['71A_chg_dtls'] = df[":71A:"]

# %%
# %%time

def _71fCurAmt(row, col):
    return pd.Series(re.split("(^[A-Z][A-Z][A-Z])([0-9]*,[0-9]*)", row[col])[1:3] 
                     if len(row[col]) > 0 else [''] * 2, 
                     index=['cur', 'amt'])

def serial_proc_71fCurAmt(df, col):
    apply_partial = partial(_71fCurAmt, col=col)
    df[["71f_chg_dtls_cur", "71f_chg_dtls_amt"]] = df.apply(apply_partial, axis=1)
    return df

dfm[["71f_chg_dtls_cur", "71f_chg_dtls_amt"]] = parallel_calc(df, serial_proc_71fCurAmt, 8, ':71F:') \
                                                        [["71f_chg_dtls_cur", "71f_chg_dtls_amt"]]
# Out:
# CPU times: user 3.81 s, sys: 1.22 s, total: 5.03 s
# Wall time: 57.7 s

# %%
# %%time
dfm['33b_orig_ord_amt'] = pd.to_numeric(dfm['33b_orig_ord_amt'].apply(lambda x: x.replace(',', '.')))
dfm['71f_chg_dtls_amt'] = pd.to_numeric(dfm['71f_chg_dtls_amt'].apply(lambda x: x.replace(',', '.')))
# Out:
# CPU times: user 336 ms, sys: 4.32 ms, total: 341 ms
# Wall time: 340 ms

# %%
dfm
# Out:
#        32a_val_dt 33b_cur  33b_orig_ord_amt  \
# 0      2021-08-13     RUB        1544103.68
# 1      2021-08-13     RUB         912070.95
# 2      2021-08-13     RUB       21760302.59
# 3      2021-08-13     RUB         878587.53
# 4      2021-08-13     RUB        6696355.97
# ...           ...     ...               ...
# 379521 2021-08-13     USD           8339.00
# 379522 2021-08-13     USD           4001.56
# 379523 2021-08-13     USD           4456.00
# 379524 2021-08-13     USD           8836.10
# 379525 2021-08-13     USD           4031.02
#
#                               50a_payor_lon 50a_payor_lat  \
# 0       /0000000000000000000000000000009621   BIC68DF2C94
# 1       /0000000000000000000000000000007346   BIC68DF2C94
# 2       /0000000000000000000000000000005305   BIC68DF2C94
# 3       /0000000000000000000000000000004127   BIC68DF2C94
# 4       /0000000000000000000000000000006978   BIC68DF2C94
# ...                                     ...           ...
# 379521  /0000000000000000000000000000003030   BIC6A94AE24
# 379522
# 379523
# 379524  /0000000000000000000000000000007977   BIC6A94AE24
# 379525
#
#            50f_payor_acct_nm:     50f_payor_name:        50f_payor_add_ln_1  \
# 0
# 1
# 2
# 3
# 4
# ...                       ...                 ...                       ...
# 379521
# 379522  DRLC US VA 0000008040    EMILIJA MITCHELL    345256 YELLOW BRICK RD
# 379523  DRLC US VA 0000009910      JOO-WON GARCIA    521469 LAKE POINTE AVE
# 379524
# 379525
#
#        50f_payor_add_ln_2   52a_sender  ... 50k_payor_add_lon  \
# 0                          BIC68DF2C94  ...
# 1                          BIC68DF2C94  ...
# 2                          BIC68DF2C94  ...
# 3                          BIC68DF2C94  ...
# 4                          BIC68DF2C94  ...
# ...                   ...          ...  ...               ...
# 379521                     BIC6A94AE24  ...
# 379522         US LINCOLN  BIC6A94AE24  ...
# 379523         US MIFFLIN  BIC6A94AE24  ...
# 379524                     BIC6A94AE24  ...
# 379525                     BIC6A94AE24  ...          -100.245
#
#                           59f_ben_acct_num:         59f_ben_name  \
# 0        0000000000000000000000000000006099          ANGEL JAMES
# 1        0000000000000000000000000000000874          JAKUB EVANS
# 2        0000000000000000000000000000005436        ZIGA MITCHELL
# 3        0000000000000000000000000000008707          YAEL DEMERS
# 4        0000000000000000000000000000004326          NOEL PLANTE
# ...                                     ...                  ...
# 379521   0000000000000000000000000000003627       JESSE LEFEBVRE
# 379522   0000000000000000000000000000009377        SULTAN OZTURK
# 379523   0000000000000000000000000000001708    DIMITRIOS PASCUAL
# 379524   0000000000000000000000000000005070         ADAMA YILDIZ
# 379525   0000000000000000000000000000000600         CLARA SAVARD
#
#                 59f_ben_add_ln_1          59f_ben_add_ln_2 59f_ben_add_lat  \
# 0               1789 PHILLIPS RD               US GLENDALE         34.1469
# 1                 369653 PEAR ST                  US WELLS         47.5664
# 2                131041 DEBRA DR                 US GROVER         42.7956
# 3             50438 HAYMARKET ST                  US MOORE         35.8156
# 4                43790 MOSHER CT               US WAUCHULA         27.5473
# ...                          ...                       ...             ...
# 379521        147085 CAPITOL AVE    US SOUTH SAN FRANCISCO         37.6535
# 379522       120952 PONDEROSA DR               US WARETOWN         39.7939
# 379523     134541 E NORTHGATE CT          US COMMERCE CITY         39.8083
# 379524    55827 PRESERVATION WAY             US ESTES PARK         40.3664
# 379525        216562 WINDFALL CT                  US GALAX         36.6612
#
#        59f_ben_add_lon 71A_chg_dtls 71f_chg_dtls_cur 71f_chg_dtls_amt
# 0             -118.248          SHA                               NaN
# 1             -99.6509          BEN              RUB              0.0
# 2             -110.929          SHA                               NaN
# 3              -101.91          SHA                               NaN
# 4             -81.8115          SHA                               NaN
# ...                ...          ...              ...              ...
# 379521        -122.417          SHA                               NaN
# 379522        -74.2232          BEN              USD              0.0
# 379523        -104.934          OUR                               NaN
# 379524        -105.503          SHA                               NaN
# 379525         -80.924          BEN              USD              0.0
#
# [379526 rows x 28 columns]

# %%
end = time.perf_counter()

# %%
print(f"Total time elasped : {(end - start)/60:.2f} minutes !!")
# Out:
# Total time elasped : 10.69 minutes !!

# %%
# %%time
dfm.to_csv('data/hackathon_parsed_format_a.csv', index = False)
# Out:
# CPU times: user 5.76 s, sys: 74.8 ms, total: 5.84 s
# Wall time: 5.84 s
